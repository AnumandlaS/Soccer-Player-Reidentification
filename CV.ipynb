# %% [markdown]
# <a href="https://colab.research.google.com/github/AnumandlaS/Soccer-Player-Reidentification/blob/main/CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics opencv-python torch torchvision scipy numpy
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.163-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (1.15.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (11.2.1)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.11/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.11/dist-packages (from ultralytics) (2.2.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.1.4->ultralytics) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.23.0->ultralytics) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Downloading ultralytics-8.3.163-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 27.0 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.6 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 7.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 10.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 48.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, ultralytics-thop, ultralytics
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 ultralytics-8.3.163 ultralytics-thop-2.0.14

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from scipy.spatial import distance
import torch
from torchvision.models import resnet18
from torchvision import transforms
from PIL import Image
import json
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# Load the fine-tuned YOLOv11 model
model = YOLO("/content/best.pt")  # Replace with your .pt file path

# Load videos
broadcast_cap = cv2.VideoCapture("/content/broadcast.mp4")
tacticam_cap = cv2.VideoCapture("/content/tacticam.mp4")

# %%
# Check if videos opened successfully
if not broadcast_cap.isOpened() or not tacticam_cap.isOpened():
    print("Error: Could not open one or both video files.")
    exit()

# %%
# Initialize ResNet for appearance feature extraction
resnet = resnet18(pretrained=True).eval().cuda() if torch.cuda.is_available() else resnet18(pretrained=True).eval()
preprocess = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 146MB/s]

# %%
# Store player tracks and features
broadcast_tracks = {}  # {track_id: [frames, bboxes, features]}
tacticam_tracks = {}   # {track_id: [frames, bboxes, features]}
player_mapping = {}    # {tacticam_id: broadcast_id}

# %%
# Function to extract appearance features from a bounding box
def extract_features(frame, bbox):
    x1, y1, x2, y2 = map(int, bbox)
    crop = frame[y1:y2, x1:x2]
    if crop.size == 0:
        return None
    crop = cv2.cvtColor(crop, cv2.COLOR_BGR2RGB)
    crop = Image.fromarray(crop)
    crop = preprocess(crop).unsqueeze(0)
    if torch.cuda.is_available():
        crop = crop.cuda()
    with torch.no_grad():
        features = resnet(crop).cpu().numpy().flatten()
    return features

# %%
# Process videos frame by frame
frame_idx = 0
while broadcast_cap.isOpened() and tacticam_cap.isOpened():
    ret_b, frame_b = broadcast_cap.read()
    ret_t, frame_t = tacticam_cap.read()

    if not ret_b or not ret_t:
        break  # End of one or both videos

    # Detect and track players in broadcast video
    results_b = model.track(frame_b, persist=True, tracker="bytetrack.yaml")
    for det in results_b[0].boxes:
        if det.id is None:
            continue
        track_id = int(det.id)
        bbox = det.xyxy[0].cpu().numpy()  # [x1, y1, x2, y2]
        conf = det.conf.cpu().numpy()
        if conf < 0.5:  # Confidence threshold
            continue
        features = extract_features(frame_b, bbox)
        if features is None:
            continue
        if track_id not in broadcast_tracks:
            broadcast_tracks[track_id] = {"frames": [], "bboxes": [], "features": []}
        broadcast_tracks[track_id]["frames"].append(frame_idx)
        broadcast_tracks[track_id]["bboxes"].append(bbox)
        broadcast_tracks[track_id]["features"].append(features)

    # Detect and track players in tacticam video
    results_t = model.track(frame_t, persist=True, tracker="bytetrack.yaml")
    for det in results_t[0].boxes:
        if det.id is None:
            continue
        track_id = int(det.id)
        bbox = det.xyxy[0].cpu().numpy()
        conf = det.conf.cpu().numpy()
        if conf < 0.5:
            continue
        features = extract_features(frame_t, bbox)
        if features is None:
            continue
        if track_id not in tacticam_tracks:
            tacticam_tracks[track_id] = {"frames": [], "bboxes": [], "features": []}
        tacticam_tracks[track_id]["frames"].append(frame_idx)
        tacticam_tracks[track_id]["bboxes"].append(bbox)
        tacticam_tracks[track_id]["features"].append(features)

    frame_idx += 1

# Release video captures
broadcast_cap.release()
tacticam_cap.release()

# Match players across videos based on appearance features
for t_id, t_data in tacticam_tracks.items():
    t_features = np.mean(t_data["features"], axis=0)  # Average features over frames
    min_dist = float("inf")
    best_match = None
    for b_id, b_data in broadcast_tracks.items():
        b_features = np.mean(b_data["features"], axis=0)
        dist = distance.cosine(t_features, b_features)
        if dist < min_dist:
            min_dist = dist
            best_match = b_id
    if min_dist < 0.5:  # Threshold for feature similarity
        player_mapping[t_id] = best_match

# Save mapping results
with open("player_mapping.json", "w") as f:
    json.dump(player_mapping, f, indent=4)
# Out:
# requirements: Ultralytics requirement ['lap>=0.5.12'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 0.9s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# 0: 384x640 3 players, 67.4ms
# Speed: 16.5ms preprocess, 67.4ms inference, 392.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 3 referees, 55.5ms
# Speed: 2.8ms preprocess, 55.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 55.6ms
# Speed: 5.1ms preprocess, 55.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 2 referees, 55.5ms
# Speed: 2.9ms preprocess, 55.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 5 players, 42.0ms
# Speed: 3.8ms preprocess, 42.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 22 players, 1 referee, 41.9ms
# Speed: 3.0ms preprocess, 41.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 3 players, 187.6ms
# Speed: 2.8ms preprocess, 187.6ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 23 players, 1 referee, 39.3ms
# Speed: 3.1ms preprocess, 39.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 players, 37.3ms
# Speed: 4.5ms preprocess, 37.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 ball, 22 players, 1 referee, 36.1ms
# Speed: 2.9ms preprocess, 36.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 44.4ms
# Speed: 3.5ms preprocess, 44.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 35.7ms
# Speed: 3.4ms preprocess, 35.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.1ms
# Speed: 3.1ms preprocess, 33.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 35.3ms
# Speed: 2.5ms preprocess, 35.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.3ms
# Speed: 3.1ms preprocess, 33.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 36.0ms
# Speed: 2.3ms preprocess, 36.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.5ms
# Speed: 3.3ms preprocess, 34.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.1ms
# Speed: 3.3ms preprocess, 33.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.5ms
# Speed: 3.1ms preprocess, 33.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.6ms
# Speed: 3.3ms preprocess, 33.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 35.2ms
# Speed: 3.4ms preprocess, 35.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.5ms
# Speed: 3.5ms preprocess, 34.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.0ms
# Speed: 2.7ms preprocess, 34.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.0ms
# Speed: 3.7ms preprocess, 34.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.0ms
# Speed: 2.8ms preprocess, 34.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.9ms
# Speed: 3.2ms preprocess, 33.9ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.4ms
# Speed: 2.9ms preprocess, 33.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.8ms
# Speed: 2.8ms preprocess, 34.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.5ms
# Speed: 3.5ms preprocess, 33.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.6ms
# Speed: 2.9ms preprocess, 33.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.6ms
# Speed: 3.1ms preprocess, 33.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 35.6ms
# Speed: 2.8ms preprocess, 35.6ms inference, 3.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 32.4ms
# Speed: 2.9ms preprocess, 32.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.7ms
# Speed: 2.6ms preprocess, 34.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 32.9ms
# Speed: 2.7ms preprocess, 32.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.4ms
# Speed: 2.8ms preprocess, 34.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.3ms
# Speed: 2.8ms preprocess, 33.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.8ms
# Speed: 2.9ms preprocess, 33.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.4ms
# Speed: 2.9ms preprocess, 33.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.1ms
# Speed: 2.7ms preprocess, 33.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.3ms
# Speed: 2.7ms preprocess, 33.3ms inference, 3.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.4ms
# Speed: 2.6ms preprocess, 33.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 35.0ms
# Speed: 2.8ms preprocess, 35.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.3ms
# Speed: 2.9ms preprocess, 33.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.6ms
# Speed: 3.3ms preprocess, 34.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 38.2ms
# Speed: 3.1ms preprocess, 38.2ms inference, 6.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 32.1ms
# Speed: 2.5ms preprocess, 32.1ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.5ms
# Speed: 3.9ms preprocess, 33.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.6ms
# Speed: 2.7ms preprocess, 33.6ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 32.3ms
# Speed: 3.2ms preprocess, 32.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 35.3ms
# Speed: 2.7ms preprocess, 35.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.7ms
# Speed: 3.0ms preprocess, 33.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.5ms
# Speed: 3.0ms preprocess, 34.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.4ms
# Speed: 2.9ms preprocess, 33.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.7ms
# Speed: 2.9ms preprocess, 34.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.3ms
# Speed: 3.2ms preprocess, 33.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.7ms
# Speed: 2.9ms preprocess, 34.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.5ms
# Speed: 7.8ms preprocess, 33.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.8ms
# Speed: 2.6ms preprocess, 34.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.2ms
# Speed: 2.7ms preprocess, 34.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 35.1ms
# Speed: 2.7ms preprocess, 35.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.5ms
# Speed: 3.8ms preprocess, 33.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.9ms
# Speed: 3.7ms preprocess, 33.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.8ms
# Speed: 3.0ms preprocess, 33.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.7ms
# Speed: 2.7ms preprocess, 34.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.8ms
# Speed: 2.6ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.0ms
# Speed: 3.3ms preprocess, 33.0ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 35.4ms
# Speed: 2.5ms preprocess, 35.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.8ms
# Speed: 2.8ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.7ms
# Speed: 3.5ms preprocess, 33.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.7ms
# Speed: 3.0ms preprocess, 33.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 35.2ms
# Speed: 2.8ms preprocess, 35.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 45.0ms
# Speed: 3.1ms preprocess, 45.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.0ms
# Speed: 3.0ms preprocess, 33.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 36.5ms
# Speed: 3.0ms preprocess, 36.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 35.2ms
# Speed: 2.8ms preprocess, 35.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.7ms
# Speed: 2.8ms preprocess, 34.7ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.5ms
# Speed: 2.8ms preprocess, 34.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.9ms
# Speed: 2.9ms preprocess, 33.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 45.7ms
# Speed: 2.8ms preprocess, 45.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 32.6ms
# Speed: 3.6ms preprocess, 32.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 35.1ms
# Speed: 3.4ms preprocess, 35.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.3ms
# Speed: 3.3ms preprocess, 34.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 35.2ms
# Speed: 3.0ms preprocess, 35.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 32.9ms
# Speed: 4.3ms preprocess, 32.9ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.7ms
# Speed: 2.9ms preprocess, 33.7ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 32.7ms
# Speed: 3.1ms preprocess, 32.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.1ms
# Speed: 3.1ms preprocess, 33.1ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 36.4ms
# Speed: 3.1ms preprocess, 36.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 32.6ms
# Speed: 3.1ms preprocess, 32.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.3ms
# Speed: 3.2ms preprocess, 33.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.3ms
# Speed: 3.0ms preprocess, 33.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 32.7ms
# Speed: 3.1ms preprocess, 32.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 32.7ms
# Speed: 3.0ms preprocess, 32.7ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 32.5ms
# Speed: 3.5ms preprocess, 32.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.1ms
# Speed: 3.2ms preprocess, 33.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.7ms
# Speed: 3.0ms preprocess, 33.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.2ms
# Speed: 3.4ms preprocess, 33.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.3ms
# Speed: 4.5ms preprocess, 33.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.2ms
# Speed: 4.2ms preprocess, 33.2ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.4ms
# Speed: 3.1ms preprocess, 33.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.2ms
# Speed: 3.2ms preprocess, 33.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.4ms
# Speed: 3.6ms preprocess, 33.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 32.8ms
# Speed: 3.0ms preprocess, 32.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.1ms
# Speed: 3.1ms preprocess, 33.1ms inference, 2.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 32.9ms
# Speed: 3.0ms preprocess, 32.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.4ms
# Speed: 2.8ms preprocess, 33.4ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.0ms
# Speed: 3.3ms preprocess, 33.0ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.5ms
# Speed: 2.9ms preprocess, 33.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 32.9ms
# Speed: 3.1ms preprocess, 32.9ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.9ms
# Speed: 2.9ms preprocess, 34.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 35.4ms
# Speed: 3.3ms preprocess, 35.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.2ms
# Speed: 3.0ms preprocess, 33.2ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 32.8ms
# Speed: 3.5ms preprocess, 32.8ms inference, 4.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.4ms
# Speed: 3.0ms preprocess, 33.4ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.9ms
# Speed: 5.2ms preprocess, 33.9ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.2ms
# Speed: 3.2ms preprocess, 33.2ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 38.3ms
# Speed: 3.2ms preprocess, 38.3ms inference, 4.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.9ms
# Speed: 3.0ms preprocess, 33.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.4ms
# Speed: 2.7ms preprocess, 33.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.7ms
# Speed: 2.7ms preprocess, 34.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.6ms
# Speed: 3.8ms preprocess, 34.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.7ms
# Speed: 3.0ms preprocess, 34.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.4ms
# Speed: 3.4ms preprocess, 33.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 37.6ms
# Speed: 2.9ms preprocess, 37.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.3ms
# Speed: 3.4ms preprocess, 33.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.9ms
# Speed: 2.9ms preprocess, 33.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.6ms
# Speed: 2.7ms preprocess, 33.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.1ms
# Speed: 2.9ms preprocess, 34.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.7ms
# Speed: 7.2ms preprocess, 33.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.9ms
# Speed: 2.8ms preprocess, 34.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 34.2ms
# Speed: 2.8ms preprocess, 34.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.8ms
# Speed: 2.8ms preprocess, 33.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.6ms
# Speed: 3.1ms preprocess, 33.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.3ms
# Speed: 2.5ms preprocess, 34.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.4ms
# Speed: 3.1ms preprocess, 33.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.7ms
# Speed: 3.5ms preprocess, 33.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.8ms
# Speed: 3.0ms preprocess, 33.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.6ms
# Speed: 2.9ms preprocess, 33.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 39.0ms
# Speed: 3.4ms preprocess, 39.0ms inference, 3.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.4ms
# Speed: 3.2ms preprocess, 33.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.7ms
# Speed: 3.5ms preprocess, 33.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.1ms
# Speed: 3.5ms preprocess, 34.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 34.3ms
# Speed: 2.9ms preprocess, 34.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.6ms
# Speed: 2.9ms preprocess, 34.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.1ms
# Speed: 3.1ms preprocess, 33.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 35.0ms
# Speed: 3.0ms preprocess, 35.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.4ms
# Speed: 3.0ms preprocess, 33.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.2ms
# Speed: 3.0ms preprocess, 33.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.2ms
# Speed: 3.1ms preprocess, 33.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.6ms
# Speed: 3.0ms preprocess, 34.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.0ms
# Speed: 2.2ms preprocess, 33.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.6ms
# Speed: 2.7ms preprocess, 34.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.0ms
# Speed: 2.9ms preprocess, 33.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.8ms
# Speed: 2.7ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.7ms
# Speed: 2.9ms preprocess, 33.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.1ms
# Speed: 2.9ms preprocess, 34.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.3ms
# Speed: 4.0ms preprocess, 33.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.7ms
# Speed: 2.9ms preprocess, 33.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.7ms
# Speed: 2.8ms preprocess, 33.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 35.0ms
# Speed: 2.9ms preprocess, 35.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.4ms
# Speed: 2.8ms preprocess, 33.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.5ms
# Speed: 2.6ms preprocess, 34.5ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 37.0ms
# Speed: 3.0ms preprocess, 37.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.9ms
# Speed: 3.2ms preprocess, 34.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 44.0ms
# Speed: 4.6ms preprocess, 44.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.4ms
# Speed: 2.3ms preprocess, 33.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.7ms
# Speed: 2.8ms preprocess, 33.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 34.2ms
# Speed: 3.1ms preprocess, 34.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 35.6ms
# Speed: 2.6ms preprocess, 35.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 32.3ms
# Speed: 3.1ms preprocess, 32.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 38.8ms
# Speed: 2.5ms preprocess, 38.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 32.2ms
# Speed: 2.9ms preprocess, 32.2ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.0ms
# Speed: 3.0ms preprocess, 34.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 34.5ms
# Speed: 3.1ms preprocess, 34.5ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.3ms
# Speed: 2.7ms preprocess, 33.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.9ms
# Speed: 2.9ms preprocess, 33.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.7ms
# Speed: 2.5ms preprocess, 34.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.8ms
# Speed: 2.9ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.2ms
# Speed: 2.9ms preprocess, 34.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.2ms
# Speed: 4.2ms preprocess, 33.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 33.2ms
# Speed: 3.4ms preprocess, 33.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.8ms
# Speed: 3.3ms preprocess, 33.8ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 players, 34.1ms
# Speed: 3.4ms preprocess, 34.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 32.7ms
# Speed: 3.0ms preprocess, 32.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.3ms
# Speed: 2.9ms preprocess, 34.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.2ms
# Speed: 3.4ms preprocess, 33.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.4ms
# Speed: 3.0ms preprocess, 34.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.7ms
# Speed: 3.7ms preprocess, 33.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.9ms
# Speed: 3.1ms preprocess, 34.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 34.7ms
# Speed: 3.5ms preprocess, 34.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.4ms
# Speed: 2.7ms preprocess, 34.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 34.7ms
# Speed: 3.0ms preprocess, 34.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.0ms
# Speed: 2.7ms preprocess, 34.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.7ms
# Speed: 3.4ms preprocess, 33.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.1ms
# Speed: 3.0ms preprocess, 34.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.5ms
# Speed: 2.7ms preprocess, 33.5ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.4ms
# Speed: 2.9ms preprocess, 33.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.7ms
# Speed: 3.1ms preprocess, 33.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.8ms
# Speed: 2.9ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.5ms
# Speed: 3.5ms preprocess, 33.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.7ms
# Speed: 2.8ms preprocess, 33.7ms inference, 2.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.9ms
# Speed: 3.5ms preprocess, 33.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.5ms
# Speed: 3.0ms preprocess, 33.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.7ms
# Speed: 3.5ms preprocess, 33.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.4ms
# Speed: 2.9ms preprocess, 33.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.7ms
# Speed: 7.4ms preprocess, 33.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.2ms
# Speed: 3.1ms preprocess, 34.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.5ms
# Speed: 6.5ms preprocess, 33.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.2ms
# Speed: 2.8ms preprocess, 34.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.6ms
# Speed: 3.0ms preprocess, 33.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.4ms
# Speed: 2.9ms preprocess, 34.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.1ms
# Speed: 2.8ms preprocess, 33.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.5ms
# Speed: 2.9ms preprocess, 33.5ms inference, 8.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 32.4ms
# Speed: 3.2ms preprocess, 32.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.3ms
# Speed: 2.8ms preprocess, 34.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.8ms
# Speed: 3.1ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.8ms
# Speed: 4.1ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.4ms
# Speed: 3.2ms preprocess, 33.4ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.6ms
# Speed: 2.9ms preprocess, 34.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 45.8ms
# Speed: 3.4ms preprocess, 45.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 32.5ms
# Speed: 3.0ms preprocess, 32.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.7ms
# Speed: 3.0ms preprocess, 33.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.7ms
# Speed: 2.9ms preprocess, 34.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.6ms
# Speed: 3.1ms preprocess, 33.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.2ms
# Speed: 3.2ms preprocess, 34.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.5ms
# Speed: 2.2ms preprocess, 33.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.7ms
# Speed: 3.1ms preprocess, 33.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.6ms
# Speed: 3.1ms preprocess, 33.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.5ms
# Speed: 3.0ms preprocess, 33.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 32.0ms
# Speed: 4.2ms preprocess, 32.0ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.8ms
# Speed: 3.1ms preprocess, 34.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.2ms
# Speed: 3.1ms preprocess, 33.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.4ms
# Speed: 3.1ms preprocess, 34.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 38.4ms
# Speed: 2.9ms preprocess, 38.4ms inference, 6.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.6ms
# Speed: 3.0ms preprocess, 33.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.9ms
# Speed: 3.3ms preprocess, 33.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.6ms
# Speed: 3.0ms preprocess, 34.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 34.0ms
# Speed: 3.1ms preprocess, 34.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 35.0ms
# Speed: 3.1ms preprocess, 35.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.9ms
# Speed: 3.5ms preprocess, 33.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.5ms
# Speed: 2.1ms preprocess, 33.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 33.6ms
# Speed: 3.1ms preprocess, 33.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 34.4ms
# Speed: 3.0ms preprocess, 34.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 players, 34.3ms
# Speed: 3.1ms preprocess, 34.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 33.8ms
# Speed: 3.1ms preprocess, 33.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.1ms
# Speed: 3.7ms preprocess, 34.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 35.4ms
# Speed: 4.0ms preprocess, 35.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 goalkeeper, 2 players, 35.4ms
# Speed: 3.2ms preprocess, 35.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 38.6ms
# Speed: 3.0ms preprocess, 38.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 goalkeepers, 1 player, 33.3ms
# Speed: 3.0ms preprocess, 33.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 36.2ms
# Speed: 3.0ms preprocess, 36.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 33.6ms
# Speed: 2.7ms preprocess, 33.6ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 35.6ms
# Speed: 2.8ms preprocess, 35.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 (no detections), 34.2ms
# Speed: 3.1ms preprocess, 34.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 36.3ms
# Speed: 3.1ms preprocess, 36.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 35.0ms
# Speed: 2.3ms preprocess, 35.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 player, 36.8ms
# Speed: 2.9ms preprocess, 36.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)

# %%
# Optional: Visualize results by annotating videos
def annotate_video(video_path, tracks, output_path):
    cap = cv2.VideoCapture(video_path)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    out = cv2.VideoWriter(output_path, cv2.VideoWriter_fourcc(*"mp4v"), fps, (width, height))

    frame_idx = 0
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        for track_id, data in tracks.items():
            for f_idx, bbox in zip(data["frames"], data["bboxes"]):
                if f_idx == frame_idx:
                    x1, y1, x2, y2 = map(int, bbox)
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    cv2.putText(frame, f"ID: {track_id}", (x1, y1-10),
                               cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
        out.write(frame)
        frame_idx += 1

    cap.release()
    out.release()

# %%
annotate_video("broadcast.mp4", broadcast_tracks, "broadcast_annotated.mp4")
annotate_video("tacticam.mp4", tacticam_tracks, "tacticam_annotated.mp4")

print("Player mapping completed. Results saved in 'player_mapping.json'.")
print("Annotated videos saved as 'broadcast_annotated.mp4' and 'tacticam_annotated.mp4'.")
# Out:
# Player mapping completed. Results saved in 'player_mapping.json'.
# Annotated videos saved as 'broadcast_annotated.mp4' and 'tacticam_annotated.mp4'.
